# %% [markdown]
# # Start of the file
# -   robust MAD normalization and clipping, k=25
# -   early stopping analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from collections import Counter
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
import hdbscan
import os
import torch
from torch.nn import functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
from torch.utils.data import DataLoader, Dataset
from sklearn.manifold import TSNE
# import pacmap
import pickle
from sklearn.model_selection import train_test_split

print(torch.__version__)
print(torch.cuda.is_available())  # Check if CUDA is available (if using GPU)
print(torch.cuda.device_count())  # Check how many GPUs are available
print(torch.cuda.get_device_name(0))  # Get the name of the first GPU
print(torch.cuda.current_device())  # Get the current GPU device

# Check if cuDNN is enabled
print(torch.backends.cudnn.enabled)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# 2.6.0+cu118
# True
# 1
# NVIDIA GeForce RTX 4060 Ti
# 0
# True
# cuda:0

# %% [markdown]
# # Preprocess

# %%
# load the TESS data from pickle file files_dataframe.pickle

with open("files_dataframe.pickle", "rb") as f:
  files_dataframe = pickle.load(f)

# %%
from scipy.stats import median_abs_deviation
from tqdm import tqdm

def preprocess_lcs_per_object(df, set='train'):
    """
    Preprocess TESS light curves with per-object normalization and uncertainty weighting.
    
    Key changes from original:
    1. Per-object normalization (median + robust MAD scaling)
    2. Inverse-variance weighting using uncertainties
    3. Outlier handling using robust statistics per object
    4. Preserves astrophysical information while normalizing scale
    
    Parameters
    ----------
    df : pandas.DataFrame
        Input dataframe with columns: 'object_name', 'tess_flux', 'tess_uncert', 'relative_time'
    set : str
        Dataset identifier ('train', 'val', 'test')
    
    Returns
    -------
    oids_used : list
        Object IDs that passed preprocessing
    target_class : list
        Class labels (if available) or object names
    data : list of np.array
        Normalized time-flux pairs for each object
    uncertainties : list of np.array
        Scaled uncertainties (time-uncertainty pairs)
    weights : list of np.array
        Inverse-variance weights for each data point
    normalization_params : dict
        Parameters used for normalization (for inverse transformation)
    """
    
    # Clean data
    df = df.copy()
    df = df[~df['tess_flux'].isna() & ~df['tess_uncert'].isna()]
    
    oids = np.unique(df['object_name'])
    
    data = []
    uncertainties = []
    weights = []
    target_class = []
    oids_used = []
    normalization_params = {}  # Store for potential inverse transformation
    
    print(f"=== Preprocessing with per-object normalization ===")
    print(f"Number of objects: {len(oids)}")
    
    for oid in tqdm(oids, desc=f"Processing {set} objects"):
        lc = df[df['object_name'] == oid].copy()
        
        if len(lc) < 20:  # Minimum points requirement
            continue
        
        # 1. Handle extreme outliers per object using robust statistics
        # Use median and MAD instead of mean/std for outlier detection
        median_flux = np.median(lc['tess_flux'])
        mad_flux = median_abs_deviation(lc['tess_flux'], scale='normal')
        
        # Define outlier bounds (e.g., median ± 5*MAD)
        # k = 25 for extreme clipping
        
        lower_bound = median_flux - 25 * mad_flux
        upper_bound = median_flux + 25 * mad_flux
        
        # Clip extreme outliers (not all high/low values, just extremes)
        n_extreme = ((lc['tess_flux'] < lower_bound) | (lc['tess_flux'] > upper_bound)).sum()
        if n_extreme > 0:
            # Cap extreme values at bounds (preserves more data than removal)
            lc.loc[lc['tess_flux'] < lower_bound, 'tess_flux'] = lower_bound
            lc.loc[lc['tess_flux'] > upper_bound, 'tess_flux'] = upper_bound
        
        # 2. PER-OBJECT NORMALIZATION
        # Calculate robust normalization parameters
        robust_median = np.median(lc['tess_flux'])
        robust_mad = median_abs_deviation(lc['tess_flux'], scale='normal')
        
        # Handle edge case: very small or zero variability
        if robust_mad < 1e-10:
            # Use standard deviation as fallback
            robust_mad = np.std(lc['tess_flux'])
            if robust_mad < 1e-10:
                robust_mad = 1.0  # Avoid division by zero
        
        # Normalize flux: (flux - median) / robust_mad
        # This gives zero median, unit robust variance
        flux_normalized = (lc['tess_flux'] - robust_median) / robust_mad
        
        # Scale uncertainties by the same factor
        uncert_scaled = lc['tess_uncert'] / robust_mad
        
        # 3. INVERSE-VARIANCE WEIGHTING
        # Weight = 1/σ² (inverse variance)
        # Add small epsilon to avoid division by zero
        epsilon = 1e-10
        weights_raw = 1.0 / (uncert_scaled**2 + epsilon)
        
        # Normalize weights to have max weight = 1 (optional but helps training)
        if weights_raw.max() > 0:
            weights_normalized = weights_raw / weights_raw.max()
        else:
            weights_normalized = np.ones_like(weights_raw)
        
        # 4. Time normalization (relative to start)
        time_normalized = lc['relative_time'] - np.min(lc['relative_time'])
        
        # 5. Store normalization parameters for this object
        normalization_params[oid] = {
            'median': robust_median,
            'mad': robust_mad,
            'n_points': len(lc),
            'n_extreme_clipped': n_extreme
        }
        
        # 6. Subsampling to fixed length (if needed for your model)
        if len(lc) > 100:
            # IMPORTANT: Sample while preserving time order and uncertainties
            indices = np.linspace(0, len(lc)-1, 100, dtype=int)
            flux_normalized = flux_normalized.iloc[indices]
            time_normalized = time_normalized.iloc[indices]
            uncert_scaled = uncert_scaled.iloc[indices]
            weights_normalized = weights_normalized[indices]
        
        elif len(lc) < 30:  # Skip objects with too few points after potential subsampling
            continue
        
        # 7. Prepare output arrays
        # Data: [time, normalized_flux]
        data.append(np.column_stack([time_normalized.values, flux_normalized.values]))
        
        # Uncertainties: [time, scaled_uncertainty]
        uncertainties.append(np.column_stack([time_normalized.values, uncert_scaled.values]))
        
        # Weights: inverse-variance weights
        weights.append(weights_normalized)
        
        # Store object info
        oids_used.append(oid)
        target_class.append(oid)  # Or use actual class if available
        
        # Optional: Store class label if available in dataframe
        if 'class' in lc.columns:
            target_class[-1] = lc['class'].iloc[0]
    
    print(f"=== Preprocessing complete ===")
    print(f"Processed objects: {len(oids_used)} / {len(oids)}")
    print(f"Average points per object: {np.mean([len(d) for d in data]):.1f}")
    
    # Print summary statistics
    if normalization_params:
        medians = [p['median'] for p in normalization_params.values()]
        mads = [p['mad'] for p in normalization_params.values()]
        print(f"Median of medians: {np.median(medians):.2f}")
        print(f"Median MAD: {np.median(mads):.2f}")
        print(f"Total extreme values clipped: {sum([p['n_extreme_clipped'] for p in normalization_params.values()])}")
    
    return oids_used, target_class, data, uncertainties, weights, normalization_params


# Use the enhanced preprocessing
all_ids, all_labels, all_data, all_uncertainties, all_weights, normalization_params = preprocess_lcs_per_object(files_dataframe)
# Out:
# === Preprocessing with per-object normalization ===
# Number of objects: 3659
# Processing train objects: 100%|██████████| 3659/3659 [00:19<00:00, 183.30it/s]
# === Preprocessing complete ===
# Processed objects: 3593 / 3659
# Average points per object: 46.2
# Median of medians: 193.28
# Median MAD: 983.81
# Total extreme values clipped: 287

# %%
count = 1
for key in normalization_params.keys():
    if normalization_params[key]['n_extreme_clipped'] > 0:  
        count += 1

print(f"Number of objects with extreme clipping: {count}")
# Out:
# Number of objects with extreme clipping: 74

# %%
class UncertaintyAwareLCDataset(Dataset):
    def __init__(self, data, uncertainties, weights, targets, ids, transform=None):
        self.data = data
        self.uncertainties = uncertainties
        self.weights = weights
        self.targets = targets
        self.ids = ids
        self.lengths = [len(seq) for seq in data]
        self.transform = transform

    def __getitem__(self, index):
        data = self.data[index]
        uncertainty = self.uncertainties[index]
        weights = self.weights[index]
        targets = self.targets[index]
        ids = self.ids[index]
        lengths = self.lengths[index]

        if self.transform:
            data = self.transform(data)
            uncertainty = self.transform(uncertainty)

        return data, uncertainty, weights, targets, ids, lengths

    def __len__(self):
        return len(self.data)

def uncertainty_collate_fn(batch):
    """Enhanced collate function that handles uncertainties and weights"""
    
    data, uncertainties, weights, targets, ids, lengths = zip(*batch)

    # Convert sequences to tensors and pad them
    sequences = [torch.tensor(d, dtype=torch.float32) for d in data]
    padded_sequences = pad_sequence(sequences, batch_first=True)
    
    # Pad uncertainties
    uncertainty_sequences = [torch.tensor(u, dtype=torch.float32) for u in uncertainties]
    padded_uncertainties = pad_sequence(uncertainty_sequences, batch_first=True)
    
    # Pad weights
    weight_sequences = [torch.tensor(w, dtype=torch.float32) for w in weights]
    padded_weights = pad_sequence(weight_sequences, batch_first=True)

    # Convert other data to tensors
    targets = torch.tensor(targets)
    ids = torch.tensor(ids)
    lengths = torch.tensor(lengths)

    return padded_sequences, padded_uncertainties, padded_weights, targets, ids, lengths

# Create enhanced datasets and data loaders
all_ds = UncertaintyAwareLCDataset(
    all_data, all_uncertainties, all_weights,
    [all_labels.index(id) for id in all_labels], 
    [all_ids.index(id) for id in all_ids]
)

all_loader = DataLoader(
    all_ds,
    batch_size=128,
    num_workers=0,
    shuffle=True,
    collate_fn=uncertainty_collate_fn,
    pin_memory=torch.cuda.is_available()
)

all_loader_no_shuffle = DataLoader(
    all_ds,
    batch_size=128,
    num_workers=0,
    shuffle=False,
    collate_fn=uncertainty_collate_fn,
    pin_memory=torch.cuda.is_available()
)

# %%
train_ids, val_ids, train_labels, val_labels, train_data, val_data, \
train_uncertainties, val_uncertainties, train_weights, val_weights = train_test_split(all_ids, all_labels, all_data, 
                                                    all_uncertainties, all_weights, test_size=0.1, random_state=42)

train_final_ids = [train_ids.index(id) for id in train_ids]
train_final_labels = [train_labels.index(id) for id in train_labels]

train_ds = UncertaintyAwareLCDataset(train_data, train_uncertainties, train_weights,
                                     [train_labels.index(id) for id in train_labels], [train_ids.index(id) for id in train_ids])
train_loader = DataLoader(
    train_ds,
    batch_size=128,
    num_workers=0,
    shuffle=True,
    collate_fn=uncertainty_collate_fn,
    pin_memory=torch.cuda.is_available()
)

val_ds = UncertaintyAwareLCDataset(val_data, val_uncertainties, val_weights,
                                   [val_labels.index(id) for id in val_labels], [val_ids.index(id) for id in val_ids] )
val_loader = DataLoader(
    val_ds,
    batch_size=128,
    num_workers=0,
    shuffle=True,
    collate_fn=uncertainty_collate_fn,
    pin_memory=torch.cuda.is_available()
)

# %% [markdown]
# # Early stopping

# %%
class EarlyStopping:

    def __init__(self, patience=5, min_delta=0, path='checkpoint.pt'):
        """
        Args:
            patience (int): How many epochs to wait after last time validation loss improved.
            min_delta (float): Minimum change in the monitored quantity to qualify as an improvement.
            path (str): Path for the checkpoint to be saved to.
        """
        self.patience = patience
        self.min_delta = min_delta
        self.path = path
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss, model):
        if self.best_loss is None:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), self.path)
        print(f'Validation loss decreased ({self.best_loss:.6f} --> {val_loss:.6f}).  Saving model ...')

# %% [markdown]
# # training

# %%
from src.util import Encoder, Decoder

class UncertaintyAwareRNN_VAE(torch.nn.Module):
    """RNN-VAE that incorporates measurement uncertainties"""
    
    def __init__(self, input_size=2, hidden_size=64, latent_size=16, dropout=0.2):
        super(UncertaintyAwareRNN_VAE, self).__init__()
        self.device = device
        
        # dimensions
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.latent_size = latent_size
        self.num_layers = 4
        self.dropout = dropout
        
        self.enc = Encoder(input_size=input_size, hidden_size=hidden_size, 
                          num_layers=self.num_layers, dropout=self.dropout)
        
        self.dec = Decoder(
            input_size=latent_size,
            output_size=input_size,
            hidden_size=hidden_size,
            dropout=self.dropout,
            num_layers=self.num_layers,
        )
        
        self.fc21 = torch.nn.Linear(self.hidden_size, self.latent_size)
        self.fc22 = torch.nn.Linear(self.hidden_size, self.latent_size)
        self.fc3 = torch.nn.Linear(self.latent_size, self.hidden_size)
    
    def reparameterize(self, mu, logvar):
        if self.training:
            return mu + torch.randn(mu.shape).to(device)*torch.exp(0.5*logvar)
        else:
            return mu
    
    def forward(self, x, lengths, weights=None):
        batch_size, seq_len, feature_dim = x.shape
        
        # encode input space
        enc_output, enc_hidden = self.enc(x, lengths)
        
        # Correctly accessing the hidden state of the last layer
        enc_h = enc_hidden[-1].to(device)
        
        # extract latent variable z
        mu = self.fc21(enc_h)
        logvar = self.fc22(enc_h)
        z = self.reparameterize(mu, logvar)
        
        # initialize hidden state
        h_ = self.fc3(z)
        h_ = h_.unsqueeze(0)
        h_ = h_.repeat(self.dec.num_layers, 1, 1)
        
        # decode latent space
        z = z.repeat(1, seq_len, 1)
        z = z.view(batch_size, seq_len, self.latent_size).to(device)
        
        # initialize hidden state
        hidden = h_.contiguous()
        x_hat, hidden = self.dec(z, hidden)
        
        return x_hat, mu, logvar

def uncertainty_weighted_ELBO(x_hat, x, mu, logvar, weights=None):
    """ELBO loss with uncertainty weighting"""
    
    # Reconstruction loss with uncertainty weights
    if weights is not None:
        # Expand weights to match x shape if needed
        if weights.dim() == 2:  # [batch_size, seq_len]
            weights = weights.unsqueeze(-1)  # [batch_size, seq_len, 1]
        
        # Weighted MSE
        weighted_MSE = torch.sum(weights * (x_hat - x)**2)
    else:
        weighted_MSE = torch.nn.MSELoss(reduction='sum')(x_hat, x)
    
    # KL divergence (unchanged)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    
    return weighted_MSE + KLD

# %% [markdown]
# ## early stop training

# %%
# no validation for now
from importlib.resources import path
from pathlib import Path
from src.util import save_checkpoint, plot_model_loss


early_stopping = EarlyStopping(patience=2)

hidden_size=128
latent_size=16
nepochs = 800
num_layers = 4

model1 = UncertaintyAwareRNN_VAE(hidden_size=hidden_size, latent_size=latent_size)
model1.to(device)
optimizer = torch.optim.Adam(model1.parameters(), lr=1.e-4)

training_losses = []
validation_losses = []

# This might ALSO take a bit of time to train.
print("Beginning training...")

for epoch in range(0, nepochs):
    # set to training mode
    model1.train()
    train_loss = 0

    for x, uncertainties, weights, labels, ids, lengths in train_loader:
        x = x.to(device)
        weights = weights.to(device)
        
        x_hat, mu, logvar = model1(x, lengths)
        loss = uncertainty_weighted_ELBO(x_hat, x, mu, logvar, weights)
        train_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model1.parameters(), max_norm=1.0)
        optimizer.step()

    avg_train_loss = train_loss / len(train_loader.dataset)
    training_losses.append(avg_train_loss)

    # Validation phase
    model1.eval()
    val_loss = 0
    
    with torch.no_grad():
        for x, uncertainties, weights, labels, ids, lengths in val_loader:
            x = x.to(device)
            weights = weights.to(device)
            
            x_hat, mu, logvar = model1(x, lengths)
            loss = uncertainty_weighted_ELBO(x_hat, x, mu, logvar, weights)
            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader.dataset)
    validation_losses.append(avg_val_loss)

    print(f'Epoch {epoch} | Train: {avg_train_loss:.2f} | Val: {avg_val_loss:.2f}')

    # --- EARLY STOPPING CHECK ---
    # Call the object with the current validation loss
    early_stopping(avg_val_loss, model1)
    
    print(f'Epoch {epoch} | Train: {avg_train_loss:.2f} | Val: {avg_val_loss:.2f}')

# --- LOAD BEST MODEL ---
# After the loop breaks, load the best saved weights
model1.load_state_dict(torch.load(path))
print("Best model loaded.")

plot_model_loss(training_losses, validation_losses)
# Out:
# Beginning training...
# Epoch 0 | Train: 8246.56 | Val: 7952.64
# Validation loss decreased (7952.636285 --> 7952.636285).  Saving model ...
# Epoch 0 | Train: 8246.56 | Val: 7952.64
# Epoch 1 | Train: 6733.80 | Val: 5390.50
# Validation loss decreased (5390.501910 --> 5390.501910).  Saving model ...
# Epoch 1 | Train: 6733.80 | Val: 5390.50
# Epoch 2 | Train: 4705.59 | Val: 4213.49
# Validation loss decreased (4213.491840 --> 4213.491840).  Saving model ...
# Epoch 2 | Train: 4705.59 | Val: 4213.49
# Epoch 3 | Train: 3914.43 | Val: 3740.11
# Validation loss decreased (3740.107031 --> 3740.107031).  Saving model ...
# Epoch 3 | Train: 3914.43 | Val: 3740.11
# Epoch 4 | Train: 3537.37 | Val: 3449.64
# Validation loss decreased (3449.639844 --> 3449.639844).  Saving model ...
# Epoch 4 | Train: 3537.37 | Val: 3449.64
# Epoch 5 | Train: 3276.56 | Val: 3217.43
# Validation loss decreased (3217.426042 --> 3217.426042).  Saving model ...
# Epoch 5 | Train: 3276.56 | Val: 3217.43
# Epoch 6 | Train: 3058.47 | Val: 3011.67
# Validation loss decreased (3011.665799 --> 3011.665799).  Saving model ...
# Epoch 6 | Train: 3058.47 | Val: 3011.67
# Epoch 7 | Train: 2863.84 | Val: 2823.93
# Validation loss decreased (2823.927604 --> 2823.927604).  Saving model ...
# Epoch 7 | Train: 2863.84 | Val: 2823.93
# Epoch 8 | Train: 2683.93 | Val: 2640.61
# Validation loss decreased (2640.610938 --> 2640.610938).  Saving model ...
# Epoch 8 | Train: 2683.93 | Val: 2640.61
# Epoch 9 | Train: 2492.05 | Val: 2422.45
# Validation loss decreased (2422.452344 --> 2422.452344).  Saving model ...
# Epoch 9 | Train: 2492.05 | Val: 2422.45
# Epoch 10 | Train: 2064.30 | Val: 1429.51
# Validation loss decreased (1429.505425 --> 1429.505425).  Saving model ...
# Epoch 10 | Train: 2064.30 | Val: 1429.51
# Epoch 11 | Train: 969.58 | Val: 662.52
# Validation loss decreased (662.520790 --> 662.520790).  Saving model ...
# Epoch 11 | Train: 969.58 | Val: 662.52
# Epoch 12 | Train: 463.39 | Val: 684.59
# EarlyStopping counter: 1 out of 2
# Epoch 12 | Train: 463.39 | Val: 684.59
# Epoch 13 | Train: 360.37 | Val: 516.35
# Validation loss decreased (516.353950 --> 516.353950).  Saving model ...
# Epoch 13 | Train: 360.37 | Val: 516.35
# Epoch 14 | Train: 334.75 | Val: 533.79
# EarlyStopping counter: 1 out of 2
# Epoch 14 | Train: 334.75 | Val: 533.79
# Epoch 15 | Train: 316.79 | Val: 407.91
# Validation loss decreased (407.907726 --> 407.907726).  Saving model ...
# Epoch 15 | Train: 316.79 | Val: 407.91
# Epoch 16 | Train: 300.55 | Val: 355.24
# Validation loss decreased (355.235069 --> 355.235069).  Saving model ...
# Epoch 16 | Train: 300.55 | Val: 355.24
# Epoch 17 | Train: 291.95 | Val: 360.50
# EarlyStopping counter: 1 out of 2
# Epoch 17 | Train: 291.95 | Val: 360.50
# Epoch 18 | Train: 279.48 | Val: 387.36
# EarlyStopping counter: 2 out of 2
# Epoch 18 | Train: 279.48 | Val: 387.36
# Epoch 19 | Train: 276.51 | Val: 314.92
# Validation loss decreased (314.921408 --> 314.921408).  Saving model ...
# Epoch 19 | Train: 276.51 | Val: 314.92
# Epoch 20 | Train: 267.57 | Val: 319.80
# EarlyStopping counter: 1 out of 2
# Epoch 20 | Train: 267.57 | Val: 319.80
# Epoch 21 | Train: 260.17 | Val: 293.61
# Validation loss decreased (293.611903 --> 293.611903).  Saving model ...
# Epoch 21 | Train: 260.17 | Val: 293.61
# Epoch 22 | Train: 251.82 | Val: 272.90
# Validation loss decreased (272.898199 --> 272.898199).  Saving model ...
# Epoch 22 | Train: 251.82 | Val: 272.90
# Epoch 23 | Train: 241.96 | Val: 268.19
# Validation loss decreased (268.189388 --> 268.189388).  Saving model ...
# Epoch 23 | Train: 241.96 | Val: 268.19
# Epoch 24 | Train: 230.52 | Val: 234.01
# Validation loss decreased (234.006104 --> 234.006104).  Saving model ...
# Epoch 24 | Train: 230.52 | Val: 234.01
# Epoch 25 | Train: 221.75 | Val: 263.20
# EarlyStopping counter: 1 out of 2
# Epoch 25 | Train: 221.75 | Val: 263.20
# Epoch 26 | Train: 218.43 | Val: 241.86
# EarlyStopping counter: 2 out of 2
# Epoch 26 | Train: 218.43 | Val: 241.86
# Epoch 27 | Train: 211.47 | Val: 259.33
# EarlyStopping counter: 3 out of 2
# Epoch 27 | Train: 211.47 | Val: 259.33
# Epoch 28 | Train: 208.50 | Val: 228.81
# Validation loss decreased (228.810954 --> 228.810954).  Saving model ...
# Epoch 28 | Train: 208.50 | Val: 228.81
# Epoch 29 | Train: 205.07 | Val: 236.26
# EarlyStopping counter: 1 out of 2
# Epoch 29 | Train: 205.07 | Val: 236.26
# Epoch 30 | Train: 203.86 | Val: 209.63
# Validation loss decreased (209.634956 --> 209.634956).  Saving model ...
# Epoch 30 | Train: 203.86 | Val: 209.63
# Epoch 31 | Train: 201.91 | Val: 212.56
# EarlyStopping counter: 1 out of 2
# Epoch 31 | Train: 201.91 | Val: 212.56
# Epoch 32 | Train: 197.68 | Val: 209.59
# Validation loss decreased (209.592811 --> 209.592811).  Saving model ...
# Epoch 32 | Train: 197.68 | Val: 209.59
# Epoch 33 | Train: 195.70 | Val: 201.90
# Validation loss decreased (201.903353 --> 201.903353).  Saving model ...
# Epoch 33 | Train: 195.70 | Val: 201.90
# Epoch 34 | Train: 193.02 | Val: 204.55
# EarlyStopping counter: 1 out of 2
# Epoch 34 | Train: 193.02 | Val: 204.55
# Epoch 35 | Train: 192.12 | Val: 204.10
# EarlyStopping counter: 2 out of 2
# Epoch 35 | Train: 192.12 | Val: 204.10
# Epoch 36 | Train: 189.10 | Val: 202.41
# EarlyStopping counter: 3 out of 2
# Epoch 36 | Train: 189.10 | Val: 202.41
# Epoch 37 | Train: 187.18 | Val: 208.32
# EarlyStopping counter: 4 out of 2
# Epoch 37 | Train: 187.18 | Val: 208.32
# Epoch 38 | Train: 185.85 | Val: 192.03
# Validation loss decreased (192.032563 --> 192.032563).  Saving model ...
# Epoch 38 | Train: 185.85 | Val: 192.03
# Epoch 39 | Train: 183.85 | Val: 189.22
# Validation loss decreased (189.218419 --> 189.218419).  Saving model ...
# Epoch 39 | Train: 183.85 | Val: 189.22
# Epoch 40 | Train: 182.83 | Val: 194.68
# EarlyStopping counter: 1 out of 2
# Epoch 40 | Train: 182.83 | Val: 194.68
# Epoch 41 | Train: 180.54 | Val: 187.66
# Validation loss decreased (187.660270 --> 187.660270).  Saving model ...
# Epoch 41 | Train: 180.54 | Val: 187.66
# Epoch 42 | Train: 180.29 | Val: 183.39
# Validation loss decreased (183.392155 --> 183.392155).  Saving model ...
# Epoch 42 | Train: 180.29 | Val: 183.39
# Epoch 43 | Train: 180.39 | Val: 186.37
# EarlyStopping counter: 1 out of 2
# Epoch 43 | Train: 180.39 | Val: 186.37
# Epoch 44 | Train: 177.00 | Val: 182.75
# Validation loss decreased (182.753098 --> 182.753098).  Saving model ...
# Epoch 44 | Train: 177.00 | Val: 182.75
# Epoch 45 | Train: 176.10 | Val: 185.16
# EarlyStopping counter: 1 out of 2
# Epoch 45 | Train: 176.10 | Val: 185.16
# Epoch 46 | Train: 175.00 | Val: 189.15
# EarlyStopping counter: 2 out of 2
# Epoch 46 | Train: 175.00 | Val: 189.15
# Epoch 47 | Train: 174.13 | Val: 184.67
# EarlyStopping counter: 3 out of 2
# Epoch 47 | Train: 174.13 | Val: 184.67
# Epoch 48 | Train: 172.26 | Val: 181.43
# Validation loss decreased (181.428092 --> 181.428092).  Saving model ...
# Epoch 48 | Train: 172.26 | Val: 181.43
# Epoch 49 | Train: 171.03 | Val: 175.81
# Validation loss decreased (175.806782 --> 175.806782).  Saving model ...
# Epoch 49 | Train: 171.03 | Val: 175.81
# Epoch 50 | Train: 169.81 | Val: 183.69
# EarlyStopping counter: 1 out of 2
# Epoch 50 | Train: 169.81 | Val: 183.69
# Epoch 51 | Train: 168.62 | Val: 170.36
# Validation loss decreased (170.358827 --> 170.358827).  Saving model ...
# Epoch 51 | Train: 168.62 | Val: 170.36
# Epoch 52 | Train: 167.40 | Val: 173.56
# EarlyStopping counter: 1 out of 2
# Epoch 52 | Train: 167.40 | Val: 173.56
# Epoch 53 | Train: 166.49 | Val: 170.20
# Validation loss decreased (170.202748 --> 170.202748).  Saving model ...
# Epoch 53 | Train: 166.49 | Val: 170.20
# Epoch 54 | Train: 166.44 | Val: 180.76
# EarlyStopping counter: 1 out of 2
# Epoch 54 | Train: 166.44 | Val: 180.76
# Epoch 55 | Train: 165.07 | Val: 185.58
# EarlyStopping counter: 2 out of 2
# Epoch 55 | Train: 165.07 | Val: 185.58
# Epoch 56 | Train: 164.68 | Val: 166.59
# Validation loss decreased (166.593604 --> 166.593604).  Saving model ...
# Epoch 56 | Train: 164.68 | Val: 166.59
# Epoch 57 | Train: 164.03 | Val: 165.56
# Validation loss decreased (165.562676 --> 165.562676).  Saving model ...
# Epoch 57 | Train: 164.03 | Val: 165.56
# Epoch 58 | Train: 165.97 | Val: 166.64
# EarlyStopping counter: 1 out of 2
# Epoch 58 | Train: 165.97 | Val: 166.64
# Epoch 59 | Train: 161.90 | Val: 167.97
# EarlyStopping counter: 2 out of 2
# Epoch 59 | Train: 161.90 | Val: 167.97
# Epoch 60 | Train: 160.92 | Val: 166.63
# EarlyStopping counter: 3 out of 2
# Epoch 60 | Train: 160.92 | Val: 166.63
# Epoch 61 | Train: 160.72 | Val: 168.29
# EarlyStopping counter: 4 out of 2
# Epoch 61 | Train: 160.72 | Val: 168.29
# Epoch 62 | Train: 160.20 | Val: 163.61
# Validation loss decreased (163.610324 --> 163.610324).  Saving model ...
# Epoch 62 | Train: 160.20 | Val: 163.61
# Epoch 63 | Train: 160.70 | Val: 180.76
# EarlyStopping counter: 1 out of 2
# Epoch 63 | Train: 160.70 | Val: 180.76
# Epoch 125 | Train: 141.91 | Val: 145.22
# Epoch 126 | Train: 141.19 | Val: 151.44
# EarlyStopping counter: 1 out of 2
# Epoch 126 | Train: 141.19 | Val: 151.44
# Epoch 127 | Train: 141.58 | Val: 170.57
# EarlyStopping counter: 2 out of 2
# Epoch 127 | Train: 141.58 | Val: 170.57
# Epoch 128 | Train: 147.30 | Val: 146.20
# EarlyStopping counter: 3 out of 2
# Epoch 128 | Train: 147.30 | Val: 146.20
# Epoch 129 | Train: 140.07 | Val: 150.26
# EarlyStopping counter: 4 out of 2
# Epoch 129 | Train: 140.07 | Val: 150.26
# Epoch 130 | Train: 139.12 | Val: 151.44
# EarlyStopping counter: 5 out of 2
# Epoch 130 | Train: 139.12 | Val: 151.44
# Epoch 131 | Train: 138.87 | Val: 141.61
# Validation loss decreased (141.614423 --> 141.614423).  Saving model ...
# Epoch 131 | Train: 138.87 | Val: 141.61
# Epoch 132 | Train: 137.55 | Val: 148.74
# EarlyStopping counter: 1 out of 2
# Epoch 132 | Train: 137.55 | Val: 148.74
# Epoch 133 | Train: 136.81 | Val: 139.19
# Validation loss decreased (139.188900 --> 139.188900).  Saving model ...
# Epoch 133 | Train: 136.81 | Val: 139.19
# Epoch 134 | Train: 136.26 | Val: 147.54
# EarlyStopping counter: 1 out of 2
# Epoch 134 | Train: 136.26 | Val: 147.54
# Epoch 135 | Train: 135.63 | Val: 139.67
# EarlyStopping counter: 2 out of 2
# Epoch 135 | Train: 135.63 | Val: 139.67
# Epoch 136 | Train: 134.45 | Val: 137.36
# Validation loss decreased (137.357490 --> 137.357490).  Saving model ...
# Epoch 136 | Train: 134.45 | Val: 137.36
# Epoch 137 | Train: 134.74 | Val: 150.98
# EarlyStopping counter: 1 out of 2
# Epoch 137 | Train: 134.74 | Val: 150.98
# Epoch 138 | Train: 132.89 | Val: 139.54
# EarlyStopping counter: 2 out of 2
# Epoch 138 | Train: 132.89 | Val: 139.54
# Epoch 139 | Train: 131.11 | Val: 137.63
# EarlyStopping counter: 3 out of 2
# Epoch 139 | Train: 131.11 | Val: 137.63
# Epoch 140 | Train: 129.95 | Val: 138.27
# EarlyStopping counter: 4 out of 2
# Epoch 140 | Train: 129.95 | Val: 138.27
# Epoch 141 | Train: 129.69 | Val: 138.88
# EarlyStopping counter: 5 out of 2
# Epoch 141 | Train: 129.69 | Val: 138.88
# Epoch 142 | Train: 127.89 | Val: 133.48
# Validation loss decreased (133.481141 --> 133.481141).  Saving model ...
# Epoch 142 | Train: 127.89 | Val: 133.48
# Epoch 143 | Train: 126.41 | Val: 134.22
# EarlyStopping counter: 1 out of 2
# Epoch 143 | Train: 126.41 | Val: 134.22
# Epoch 144 | Train: 125.71 | Val: 133.54
# EarlyStopping counter: 2 out of 2
# Epoch 144 | Train: 125.71 | Val: 133.54
# Epoch 145 | Train: 123.71 | Val: 128.17
# Validation loss decreased (128.168793 --> 128.168793).  Saving model ...
# Epoch 145 | Train: 123.71 | Val: 128.17
# Epoch 146 | Train: 122.50 | Val: 129.61
# EarlyStopping counter: 1 out of 2
# Epoch 146 | Train: 122.50 | Val: 129.61
# Epoch 147 | Train: 120.88 | Val: 127.49
# Validation loss decreased (127.490025 --> 127.490025).  Saving model ...
# Epoch 147 | Train: 120.88 | Val: 127.49
# Epoch 148 | Train: 119.91 | Val: 131.65
# EarlyStopping counter: 1 out of 2
# Epoch 148 | Train: 119.91 | Val: 131.65
# Epoch 149 | Train: 119.75 | Val: 123.23
# Validation loss decreased (123.234622 --> 123.234622).  Saving model ...
# Epoch 149 | Train: 119.75 | Val: 123.23
# Epoch 150 | Train: 118.73 | Val: 124.93
# EarlyStopping counter: 1 out of 2
# Epoch 150 | Train: 118.73 | Val: 124.93
# Epoch 151 | Train: 118.46 | Val: 132.58
# EarlyStopping counter: 2 out of 2
# Epoch 151 | Train: 118.46 | Val: 132.58
# Epoch 152 | Train: 117.92 | Val: 125.48
# EarlyStopping counter: 3 out of 2
# Epoch 152 | Train: 117.92 | Val: 125.48
# Epoch 153 | Train: 117.08 | Val: 123.64
# EarlyStopping counter: 4 out of 2
# Epoch 153 | Train: 117.08 | Val: 123.64
# Epoch 154 | Train: 115.10 | Val: 123.86
# EarlyStopping counter: 5 out of 2
# Epoch 154 | Train: 115.10 | Val: 123.86
# Epoch 155 | Train: 114.00 | Val: 120.77
# Validation loss decreased (120.771685 --> 120.771685).  Saving model ...
# Epoch 155 | Train: 114.00 | Val: 120.77
# Epoch 156 | Train: 113.56 | Val: 119.68
# Validation loss decreased (119.676731 --> 119.676731).  Saving model ...
# Epoch 156 | Train: 113.56 | Val: 119.68
# Epoch 157 | Train: 113.34 | Val: 125.47
# EarlyStopping counter: 1 out of 2
# Epoch 157 | Train: 113.34 | Val: 125.47
# Epoch 158 | Train: 111.90 | Val: 129.30
# EarlyStopping counter: 2 out of 2
# Epoch 158 | Train: 111.90 | Val: 129.30
# Epoch 159 | Train: 112.39 | Val: 122.21
# EarlyStopping counter: 3 out of 2
# Epoch 159 | Train: 112.39 | Val: 122.21
# Epoch 160 | Train: 109.94 | Val: 117.04
# Validation loss decreased (117.043972 --> 117.043972).  Saving model ...
# Epoch 160 | Train: 109.94 | Val: 117.04
# Epoch 161 | Train: 109.52 | Val: 114.71
# Validation loss decreased (114.708767 --> 114.708767).  Saving model ...
# Epoch 161 | Train: 109.52 | Val: 114.71
# Epoch 162 | Train: 109.07 | Val: 116.37
# EarlyStopping counter: 1 out of 2
# Epoch 162 | Train: 109.07 | Val: 116.37
# Epoch 163 | Train: 107.93 | Val: 122.55
# EarlyStopping counter: 2 out of 2
# Epoch 163 | Train: 107.93 | Val: 122.55
# Epoch 164 | Train: 107.19 | Val: 118.98
# EarlyStopping counter: 3 out of 2
# Epoch 164 | Train: 107.19 | Val: 118.98
# Epoch 165 | Train: 106.22 | Val: 115.73
# EarlyStopping counter: 4 out of 2
# Epoch 165 | Train: 106.22 | Val: 115.73
# Epoch 166 | Train: 105.83 | Val: 112.86
# Validation loss decreased (112.861480 --> 112.861480).  Saving model ...
# Epoch 166 | Train: 105.83 | Val: 112.86
# Epoch 167 | Train: 104.77 | Val: 114.91
# EarlyStopping counter: 1 out of 2
# Epoch 167 | Train: 104.77 | Val: 114.91
# Epoch 168 | Train: 103.81 | Val: 110.96
# Validation loss decreased (110.956992 --> 110.956992).  Saving model ...
# Epoch 168 | Train: 103.81 | Val: 110.96
# Epoch 169 | Train: 103.20 | Val: 112.53
# EarlyStopping counter: 1 out of 2
# Epoch 169 | Train: 103.20 | Val: 112.53
# Epoch 170 | Train: 102.48 | Val: 111.74
# EarlyStopping counter: 2 out of 2
# Epoch 170 | Train: 102.48 | Val: 111.74
# Epoch 171 | Train: 102.81 | Val: 111.83
# EarlyStopping counter: 3 out of 2
# Epoch 171 | Train: 102.81 | Val: 111.83
# Epoch 172 | Train: 101.58 | Val: 108.83
# Validation loss decreased (108.829169 --> 108.829169).  Saving model ...
# Epoch 172 | Train: 101.58 | Val: 108.83
# Epoch 173 | Train: 100.04 | Val: 110.60
# EarlyStopping counter: 1 out of 2
# Epoch 173 | Train: 100.04 | Val: 110.60
# Epoch 174 | Train: 100.02 | Val: 112.51
# EarlyStopping counter: 2 out of 2
# Epoch 174 | Train: 100.02 | Val: 112.51
# Epoch 175 | Train: 100.08 | Val: 110.70
# EarlyStopping counter: 3 out of 2
# Epoch 175 | Train: 100.08 | Val: 110.70
# Epoch 176 | Train: 100.41 | Val: 108.65
# Validation loss decreased (108.648250 --> 108.648250).  Saving model ...
# Epoch 176 | Train: 100.41 | Val: 108.65
# Epoch 177 | Train: 98.99 | Val: 106.29
# Validation loss decreased (106.292673 --> 106.292673).  Saving model ...
# Epoch 177 | Train: 98.99 | Val: 106.29
# Epoch 178 | Train: 97.83 | Val: 109.73
# EarlyStopping counter: 1 out of 2
# Epoch 178 | Train: 97.83 | Val: 109.73
# Epoch 179 | Train: 98.09 | Val: 106.79
# EarlyStopping counter: 2 out of 2
# Epoch 179 | Train: 98.09 | Val: 106.79
# Epoch 180 | Train: 96.61 | Val: 108.62
# EarlyStopping counter: 3 out of 2
# Epoch 180 | Train: 96.61 | Val: 108.62
# Epoch 181 | Train: 96.54 | Val: 108.60
# EarlyStopping counter: 4 out of 2
# Epoch 181 | Train: 96.54 | Val: 108.60
# Epoch 182 | Train: 95.62 | Val: 103.16
# Validation loss decreased (103.158626 --> 103.158626).  Saving model ...
# Epoch 182 | Train: 95.62 | Val: 103.16
# Epoch 183 | Train: 94.64 | Val: 104.00
# EarlyStopping counter: 1 out of 2
# Epoch 183 | Train: 94.64 | Val: 104.00
# Epoch 184 | Train: 94.71 | Val: 110.87
# EarlyStopping counter: 2 out of 2
# Epoch 184 | Train: 94.71 | Val: 110.87
# Epoch 185 | Train: 94.56 | Val: 108.74
# EarlyStopping counter: 3 out of 2
# Epoch 185 | Train: 94.56 | Val: 108.74
# Epoch 186 | Train: 94.44 | Val: 104.06
# EarlyStopping counter: 4 out of 2
# Epoch 186 | Train: 94.44 | Val: 104.06
# Epoch 187 | Train: 93.56 | Val: 112.85
# EarlyStopping counter: 5 out of 2
# Epoch 187 | Train: 93.56 | Val: 112.85
# Epoch 188 | Train: 94.25 | Val: 106.66
# EarlyStopping counter: 6 out of 2
# Epoch 188 | Train: 94.25 | Val: 106.66
# Epoch 189 | Train: 93.84 | Val: 101.56
# Validation loss decreased (101.560612 --> 101.560612).  Saving model ...
# Epoch 189 | Train: 93.84 | Val: 101.56
# Epoch 190 | Train: 92.12 | Val: 106.29
# EarlyStopping counter: 1 out of 2
# Epoch 190 | Train: 92.12 | Val: 106.29
# Epoch 191 | Train: 92.34 | Val: 105.61
# EarlyStopping counter: 2 out of 2
# Epoch 191 | Train: 92.34 | Val: 105.61
# Epoch 192 | Train: 92.72 | Val: 107.98
# EarlyStopping counter: 3 out of 2
# Epoch 192 | Train: 92.72 | Val: 107.98
# Epoch 193 | Train: 93.04 | Val: 100.64
# Validation loss decreased (100.639917 --> 100.639917).  Saving model ...
# Epoch 193 | Train: 93.04 | Val: 100.64
# Epoch 194 | Train: 95.74 | Val: 99.58
# Validation loss decreased (99.576533 --> 99.576533).  Saving model ...
# Epoch 194 | Train: 95.74 | Val: 99.58
# Epoch 195 | Train: 91.26 | Val: 101.72
# EarlyStopping counter: 1 out of 2
# Epoch 195 | Train: 91.26 | Val: 101.72
# Epoch 196 | Train: 92.70 | Val: 102.52
# EarlyStopping counter: 2 out of 2
# Epoch 196 | Train: 92.70 | Val: 102.52
# Epoch 197 | Train: 90.51 | Val: 102.16
# EarlyStopping counter: 3 out of 2
# Epoch 197 | Train: 90.51 | Val: 102.16
# Epoch 198 | Train: 89.92 | Val: 98.60
# Validation loss decreased (98.598397 --> 98.598397).  Saving model ...
# Epoch 198 | Train: 89.92 | Val: 98.60
# Epoch 199 | Train: 90.25 | Val: 99.34
# EarlyStopping counter: 1 out of 2
# Epoch 199 | Train: 90.25 | Val: 99.34
# Epoch 200 | Train: 89.62 | Val: 98.44
# Validation loss decreased (98.437074 --> 98.437074).  Saving model ...
# Epoch 200 | Train: 89.62 | Val: 98.44
# Epoch 201 | Train: 90.48 | Val: 101.26
# EarlyStopping counter: 1 out of 2
# Epoch 201 | Train: 90.48 | Val: 101.26
# Epoch 202 | Train: 90.50 | Val: 104.14
# EarlyStopping counter: 2 out of 2
# Epoch 202 | Train: 90.50 | Val: 104.14
# Epoch 203 | Train: 88.26 | Val: 103.39
# EarlyStopping counter: 3 out of 2
# Epoch 203 | Train: 88.26 | Val: 103.39
# Epoch 204 | Train: 91.87 | Val: 98.71
# EarlyStopping counter: 4 out of 2
# Epoch 204 | Train: 91.87 | Val: 98.71
# Epoch 205 | Train: 88.85 | Val: 98.70
# EarlyStopping counter: 5 out of 2
# Epoch 205 | Train: 88.85 | Val: 98.70
# Epoch 206 | Train: 87.91 | Val: 97.45
# Validation loss decreased (97.452151 --> 97.452151).  Saving model ...
# Epoch 206 | Train: 87.91 | Val: 97.45
# Epoch 207 | Train: 88.63 | Val: 104.91
# EarlyStopping counter: 1 out of 2
# Epoch 207 | Train: 88.63 | Val: 104.91
# Epoch 208 | Train: 87.21 | Val: 99.59
# EarlyStopping counter: 2 out of 2
# Epoch 208 | Train: 87.21 | Val: 99.59
# Epoch 209 | Train: 87.46 | Val: 100.23
# EarlyStopping counter: 3 out of 2
# Epoch 209 | Train: 87.46 | Val: 100.23
# Epoch 210 | Train: 88.91 | Val: 99.30
# EarlyStopping counter: 4 out of 2
# Epoch 210 | Train: 88.91 | Val: 99.30
# Epoch 211 | Train: 87.29 | Val: 102.81
# EarlyStopping counter: 5 out of 2
# Epoch 211 | Train: 87.29 | Val: 102.81
# Epoch 212 | Train: 88.24 | Val: 107.23
# EarlyStopping counter: 6 out of 2
# Epoch 212 | Train: 88.24 | Val: 107.23
# Epoch 213 | Train: 87.61 | Val: 102.20
# EarlyStopping counter: 7 out of 2
# Epoch 213 | Train: 87.61 | Val: 102.20
# Epoch 214 | Train: 87.39 | Val: 99.76
# EarlyStopping counter: 8 out of 2
# Epoch 214 | Train: 87.39 | Val: 99.76
# Epoch 215 | Train: 87.16 | Val: 103.85
# EarlyStopping counter: 9 out of 2
# Epoch 215 | Train: 87.16 | Val: 103.85
# Epoch 216 | Train: 86.42 | Val: 99.80
# EarlyStopping counter: 10 out of 2
# Epoch 216 | Train: 86.42 | Val: 99.80
# Epoch 217 | Train: 86.33 | Val: 100.48
# EarlyStopping counter: 11 out of 2
# Epoch 217 | Train: 86.33 | Val: 100.48
# Epoch 218 | Train: 86.23 | Val: 96.53
# Validation loss decreased (96.531093 --> 96.531093).  Saving model ...
# Epoch 218 | Train: 86.23 | Val: 96.53
# Epoch 219 | Train: 86.27 | Val: 100.42
# EarlyStopping counter: 1 out of 2
# Epoch 219 | Train: 86.27 | Val: 100.42
# Epoch 220 | Train: 86.74 | Val: 98.69
# EarlyStopping counter: 2 out of 2
# Epoch 220 | Train: 86.74 | Val: 98.69
# Epoch 221 | Train: 86.99 | Val: 99.89
# EarlyStopping counter: 3 out of 2
# Epoch 221 | Train: 86.99 | Val: 99.89
# Epoch 222 | Train: 85.87 | Val: 99.80
# EarlyStopping counter: 4 out of 2
# Epoch 222 | Train: 85.87 | Val: 99.80
# Epoch 223 | Train: 84.55 | Val: 99.20
# EarlyStopping counter: 5 out of 2
# Epoch 223 | Train: 84.55 | Val: 99.20
# Epoch 224 | Train: 84.91 | Val: 93.35
# Validation loss decreased (93.353849 --> 93.353849).  Saving model ...
# Epoch 224 | Train: 84.91 | Val: 93.35
# Epoch 225 | Train: 85.69 | Val: 95.44
# EarlyStopping counter: 1 out of 2
# Epoch 225 | Train: 85.69 | Val: 95.44
# Epoch 226 | Train: 85.67 | Val: 97.72
# EarlyStopping counter: 2 out of 2
# Epoch 226 | Train: 85.67 | Val: 97.72
# Epoch 227 | Train: 84.69 | Val: 99.58
# EarlyStopping counter: 3 out of 2
# Epoch 227 | Train: 84.69 | Val: 99.58
# Epoch 228 | Train: 84.83 | Val: 95.12
# EarlyStopping counter: 4 out of 2
# Epoch 228 | Train: 84.83 | Val: 95.12
# Epoch 229 | Train: 82.68 | Val: 94.14
# EarlyStopping counter: 5 out of 2
# Epoch 229 | Train: 82.68 | Val: 94.14
# Epoch 230 | Train: 84.23 | Val: 98.23
# EarlyStopping counter: 6 out of 2
# Epoch 230 | Train: 84.23 | Val: 98.23
# Epoch 231 | Train: 83.54 | Val: 99.47
# EarlyStopping counter: 7 out of 2
# Epoch 231 | Train: 83.54 | Val: 99.47
# Epoch 232 | Train: 83.42 | Val: 100.79
# EarlyStopping counter: 8 out of 2
# Epoch 232 | Train: 83.42 | Val: 100.79
# Epoch 233 | Train: 87.25 | Val: 92.35
# Validation loss decreased (92.350420 --> 92.350420).  Saving model ...
# Epoch 233 | Train: 87.25 | Val: 92.35
# Epoch 234 | Train: 83.54 | Val: 96.59
# EarlyStopping counter: 1 out of 2
# Epoch 234 | Train: 83.54 | Val: 96.59
# Epoch 235 | Train: 82.91 | Val: 94.72
# EarlyStopping counter: 2 out of 2
# Epoch 235 | Train: 82.91 | Val: 94.72
# Epoch 236 | Train: 85.07 | Val: 94.27
# EarlyStopping counter: 3 out of 2
# Epoch 236 | Train: 85.07 | Val: 94.27
# Epoch 237 | Train: 82.51 | Val: 94.52
# EarlyStopping counter: 4 out of 2
# Epoch 237 | Train: 82.51 | Val: 94.52
# Epoch 238 | Train: 82.94 | Val: 98.49
# EarlyStopping counter: 5 out of 2
# Epoch 238 | Train: 82.94 | Val: 98.49
# Epoch 239 | Train: 84.08 | Val: 100.69
# EarlyStopping counter: 6 out of 2
# Epoch 239 | Train: 84.08 | Val: 100.69
# Epoch 240 | Train: 82.48 | Val: 93.12
# EarlyStopping counter: 7 out of 2
# Epoch 240 | Train: 82.48 | Val: 93.12
# Epoch 241 | Train: 82.85 | Val: 99.65
# EarlyStopping counter: 8 out of 2
# Epoch 241 | Train: 82.85 | Val: 99.65
# Epoch 242 | Train: 81.87 | Val: 93.93
# EarlyStopping counter: 9 out of 2
# Epoch 242 | Train: 81.87 | Val: 93.93
# Epoch 243 | Train: 82.41 | Val: 93.48
# EarlyStopping counter: 10 out of 2
# Epoch 243 | Train: 82.41 | Val: 93.48
# Epoch 244 | Train: 81.94 | Val: 99.66
# EarlyStopping counter: 11 out of 2
# Epoch 244 | Train: 81.94 | Val: 99.66
# Epoch 245 | Train: 80.99 | Val: 92.05
# Validation loss decreased (92.050269 --> 92.050269).  Saving model ...
# Epoch 245 | Train: 80.99 | Val: 92.05
# Epoch 246 | Train: 81.62 | Val: 98.41
# EarlyStopping counter: 1 out of 2
# Epoch 246 | Train: 81.62 | Val: 98.41
# Epoch 247 | Train: 80.22 | Val: 94.03
# EarlyStopping counter: 2 out of 2
# Epoch 247 | Train: 80.22 | Val: 94.03
# Epoch 248 | Train: 81.49 | Val: 105.79
# EarlyStopping counter: 3 out of 2
# Epoch 248 | Train: 81.49 | Val: 105.79
# Epoch 249 | Train: 81.60 | Val: 89.80
# Validation loss decreased (89.804902 --> 89.804902).  Saving model ...
# Epoch 249 | Train: 81.60 | Val: 89.80
# Epoch 250 | Train: 80.73 | Val: 91.01
# EarlyStopping counter: 1 out of 2
# Epoch 250 | Train: 80.73 | Val: 91.01
# Epoch 251 | Train: 80.09 | Val: 95.00
# EarlyStopping counter: 2 out of 2
# Epoch 251 | Train: 80.09 | Val: 95.00
# Epoch 252 | Train: 81.32 | Val: 105.64
# EarlyStopping counter: 3 out of 2
# Epoch 252 | Train: 81.32 | Val: 105.64
# Epoch 253 | Train: 81.24 | Val: 89.71
# Validation loss decreased (89.713582 --> 89.713582).  Saving model ...
# Epoch 253 | Train: 81.24 | Val: 89.71
# Epoch 254 | Train: 79.73 | Val: 95.07
# EarlyStopping counter: 1 out of 2
# Epoch 254 | Train: 79.73 | Val: 95.07
# Epoch 255 | Train: 80.10 | Val: 99.97
# EarlyStopping counter: 2 out of 2
# Epoch 255 | Train: 80.10 | Val: 99.97
# Epoch 256 | Train: 81.71 | Val: 91.48
# EarlyStopping counter: 3 out of 2
# Epoch 256 | Train: 81.71 | Val: 91.48
# Epoch 257 | Train: 80.82 | Val: 92.38
# EarlyStopping counter: 4 out of 2
# Epoch 257 | Train: 80.82 | Val: 92.38
# Epoch 258 | Train: 79.77 | Val: 91.08
# EarlyStopping counter: 5 out of 2
# Epoch 258 | Train: 79.77 | Val: 91.08
# Epoch 259 | Train: 78.89 | Val: 96.20
# EarlyStopping counter: 6 out of 2
# Epoch 259 | Train: 78.89 | Val: 96.20
# Epoch 260 | Train: 79.84 | Val: 92.33
# EarlyStopping counter: 7 out of 2
# Epoch 260 | Train: 79.84 | Val: 92.33
# Epoch 261 | Train: 82.09 | Val: 94.60
# EarlyStopping counter: 8 out of 2
# Epoch 261 | Train: 82.09 | Val: 94.60
# Epoch 262 | Train: 78.34 | Val: 88.31
# Validation loss decreased (88.311898 --> 88.311898).  Saving model ...
# Epoch 262 | Train: 78.34 | Val: 88.31
# Epoch 263 | Train: 81.10 | Val: 89.87
# EarlyStopping counter: 1 out of 2
# Epoch 263 | Train: 81.10 | Val: 89.87
# Epoch 264 | Train: 78.59 | Val: 90.19
# EarlyStopping counter: 2 out of 2
# Epoch 264 | Train: 78.59 | Val: 90.19
# Epoch 265 | Train: 80.25 | Val: 95.42
# EarlyStopping counter: 3 out of 2
# Epoch 265 | Train: 80.25 | Val: 95.42
# Epoch 266 | Train: 79.91 | Val: 89.05
# EarlyStopping counter: 4 out of 2
# Epoch 266 | Train: 79.91 | Val: 89.05
# Epoch 267 | Train: 78.46 | Val: 89.81
# EarlyStopping counter: 5 out of 2
# Epoch 267 | Train: 78.46 | Val: 89.81
# Epoch 268 | Train: 78.40 | Val: 93.04
# EarlyStopping counter: 6 out of 2
# Epoch 268 | Train: 78.40 | Val: 93.04
# Epoch 269 | Train: 79.53 | Val: 94.35
# EarlyStopping counter: 7 out of 2
# Epoch 269 | Train: 79.53 | Val: 94.35
# Epoch 270 | Train: 78.83 | Val: 92.15
# EarlyStopping counter: 8 out of 2
# Epoch 270 | Train: 78.83 | Val: 92.15
# Epoch 271 | Train: 77.60 | Val: 88.14
# Epoch 292 | Train: 76.74 | Val: 86.86
# EarlyStopping counter: 3 out of 2
# Epoch 292 | Train: 76.74 | Val: 86.86
# Epoch 293 | Train: 76.03 | Val: 87.67
# EarlyStopping counter: 4 out of 2
# Epoch 293 | Train: 76.03 | Val: 87.67
# Epoch 294 | Train: 74.70 | Val: 85.61
# Validation loss decreased (85.611553 --> 85.611553).  Saving model ...
# Epoch 294 | Train: 74.70 | Val: 85.61
# Epoch 295 | Train: 74.60 | Val: 91.50
# EarlyStopping counter: 1 out of 2
# Epoch 295 | Train: 74.60 | Val: 91.50
# Epoch 296 | Train: 78.02 | Val: 87.37
# EarlyStopping counter: 2 out of 2
# Epoch 296 | Train: 78.02 | Val: 87.37
# Epoch 297 | Train: 75.50 | Val: 88.60
# EarlyStopping counter: 3 out of 2
# Epoch 297 | Train: 75.50 | Val: 88.60
# Epoch 298 | Train: 74.61 | Val: 90.55
# EarlyStopping counter: 4 out of 2
# Epoch 298 | Train: 74.61 | Val: 90.55
# Epoch 299 | Train: 75.65 | Val: 84.68
# Validation loss decreased (84.683875 --> 84.683875).  Saving model ...
# Epoch 299 | Train: 75.65 | Val: 84.68
# Epoch 300 | Train: 76.49 | Val: 86.50
# EarlyStopping counter: 1 out of 2
# Epoch 300 | Train: 76.49 | Val: 86.50
# Epoch 301 | Train: 74.28 | Val: 95.78
# EarlyStopping counter: 2 out of 2
# Epoch 301 | Train: 74.28 | Val: 95.78
# Epoch 302 | Train: 74.52 | Val: 90.03
# EarlyStopping counter: 3 out of 2
# Epoch 302 | Train: 74.52 | Val: 90.03
# Epoch 303 | Train: 74.32 | Val: 93.11
# EarlyStopping counter: 4 out of 2
# Epoch 303 | Train: 74.32 | Val: 93.11
# Epoch 304 | Train: 75.88 | Val: 87.36
# EarlyStopping counter: 5 out of 2
# Epoch 304 | Train: 75.88 | Val: 87.36
# Epoch 305 | Train: 75.67 | Val: 83.51
# Validation loss decreased (83.513322 --> 83.513322).  Saving model ...
# Epoch 305 | Train: 75.67 | Val: 83.51
# Epoch 306 | Train: 74.59 | Val: 87.49
# EarlyStopping counter: 1 out of 2
# Epoch 306 | Train: 74.59 | Val: 87.49
# Epoch 307 | Train: 74.68 | Val: 84.94
# EarlyStopping counter: 2 out of 2
# Epoch 307 | Train: 74.68 | Val: 84.94
# Epoch 308 | Train: 73.88 | Val: 84.46
# EarlyStopping counter: 3 out of 2
# Epoch 308 | Train: 73.88 | Val: 84.46
# Epoch 309 | Train: 74.55 | Val: 90.01
# EarlyStopping counter: 4 out of 2
# Epoch 309 | Train: 74.55 | Val: 90.01
# Epoch 310 | Train: 74.15 | Val: 82.29
# Validation loss decreased (82.290332 --> 82.290332).  Saving model ...
# Epoch 310 | Train: 74.15 | Val: 82.29
# Epoch 311 | Train: 75.45 | Val: 88.55
# EarlyStopping counter: 1 out of 2
# Epoch 311 | Train: 75.45 | Val: 88.55
# Epoch 312 | Train: 75.22 | Val: 86.28
# EarlyStopping counter: 2 out of 2
# Epoch 333 | Train: 71.79 | Val: 83.27
# Epoch 334 | Train: 72.49 | Val: 80.83
# Validation loss decreased (80.826497 --> 80.826497).  Saving model ...
# Epoch 334 | Train: 72.49 | Val: 80.83
# Epoch 335 | Train: 74.10 | Val: 81.51
# EarlyStopping counter: 1 out of 2
# Epoch 335 | Train: 74.10 | Val: 81.51
# Epoch 336 | Train: 71.64 | Val: 86.82
# EarlyStopping counter: 2 out of 2
# Epoch 336 | Train: 71.64 | Val: 86.82
# Epoch 337 | Train: 72.67 | Val: 83.87
# EarlyStopping counter: 3 out of 2
# Epoch 337 | Train: 72.67 | Val: 83.87
# Epoch 338 | Train: 71.97 | Val: 82.61
# EarlyStopping counter: 4 out of 2
# Epoch 338 | Train: 71.97 | Val: 82.61
# Epoch 339 | Train: 71.42 | Val: 84.39
# EarlyStopping counter: 5 out of 2
# Epoch 339 | Train: 71.42 | Val: 84.39
# Epoch 340 | Train: 71.42 | Val: 80.08
# Validation loss decreased (80.076439 --> 80.076439).  Saving model ...
# Epoch 340 | Train: 71.42 | Val: 80.08
# Epoch 341 | Train: 74.59 | Val: 80.15
# EarlyStopping counter: 1 out of 2
# Epoch 341 | Train: 74.59 | Val: 80.15
# Epoch 342 | Train: 74.49 | Val: 78.42
# Validation loss decreased (78.423896 --> 78.423896).  Saving model ...
# Epoch 342 | Train: 74.49 | Val: 78.42
# Epoch 343 | Train: 71.95 | Val: 82.26
# EarlyStopping counter: 1 out of 2
# Epoch 343 | Train: 71.95 | Val: 82.26
# Epoch 344 | Train: 71.55 | Val: 80.29
# EarlyStopping counter: 2 out of 2
# Epoch 344 | Train: 71.55 | Val: 80.29
# Epoch 345 | Train: 71.55 | Val: 81.10
# EarlyStopping counter: 3 out of 2
# Epoch 345 | Train: 71.55 | Val: 81.10
# Epoch 346 | Train: 71.58 | Val: 79.13
# EarlyStopping counter: 4 out of 2
# Epoch 346 | Train: 71.58 | Val: 79.13
# Epoch 347 | Train: 73.28 | Val: 79.94
# EarlyStopping counter: 5 out of 2
# Epoch 347 | Train: 73.28 | Val: 79.94
# Epoch 348 | Train: 71.00 | Val: 82.35
# EarlyStopping counter: 6 out of 2
# Epoch 348 | Train: 71.00 | Val: 82.35
# Epoch 349 | Train: 72.25 | Val: 80.37
# EarlyStopping counter: 7 out of 2
# Epoch 349 | Train: 72.25 | Val: 80.37
# Epoch 350 | Train: 71.91 | Val: 80.87
# EarlyStopping counter: 8 out of 2
# Epoch 350 | Train: 71.91 | Val: 80.87
# Epoch 351 | Train: 71.02 | Val: 81.96
# EarlyStopping counter: 9 out of 2
# Epoch 351 | Train: 71.02 | Val: 81.96
# Epoch 352 | Train: 72.13 | Val: 84.44
# EarlyStopping counter: 10 out of 2
# Epoch 352 | Train: 72.13 | Val: 84.44
# Epoch 353 | Train: 71.70 | Val: 80.94
# EarlyStopping counter: 11 out of 2
# Epoch 353 | Train: 71.70 | Val: 80.94
# Epoch 354 | Train: 70.90 | Val: 80.55
# EarlyStopping counter: 12 out of 2
# Epoch 689 | Train: 51.49 | Val: 60.54
# Epoch 690 | Train: 50.94 | Val: 65.20
# EarlyStopping counter: 1 out of 2
# Epoch 690 | Train: 50.94 | Val: 65.20
# Epoch 691 | Train: 51.85 | Val: 65.27
# EarlyStopping counter: 2 out of 2
# Epoch 691 | Train: 51.85 | Val: 65.27
# Epoch 692 | Train: 51.29 | Val: 64.38
# EarlyStopping counter: 3 out of 2
# Epoch 692 | Train: 51.29 | Val: 64.38
# Epoch 693 | Train: 50.88 | Val: 62.76
# EarlyStopping counter: 4 out of 2
# Epoch 693 | Train: 50.88 | Val: 62.76
# Epoch 694 | Train: 54.20 | Val: 60.49
# Validation loss decreased (60.487461 --> 60.487461).  Saving model ...
# Epoch 694 | Train: 54.20 | Val: 60.49
# Epoch 695 | Train: 50.44 | Val: 66.80
# EarlyStopping counter: 1 out of 2
# Epoch 695 | Train: 50.44 | Val: 66.80
# Epoch 696 | Train: 51.66 | Val: 62.23
# EarlyStopping counter: 2 out of 2
# Epoch 696 | Train: 51.66 | Val: 62.23
# Epoch 697 | Train: 51.01 | Val: 63.91
# EarlyStopping counter: 3 out of 2
# Epoch 697 | Train: 51.01 | Val: 63.91
# Epoch 698 | Train: 50.64 | Val: 64.06
# EarlyStopping counter: 4 out of 2
# Epoch 698 | Train: 50.64 | Val: 64.06
# Epoch 699 | Train: 50.80 | Val: 63.72
# EarlyStopping counter: 5 out of 2
# Epoch 699 | Train: 50.80 | Val: 63.72
# Epoch 700 | Train: 50.54 | Val: 65.92
# EarlyStopping counter: 6 out of 2
# Epoch 700 | Train: 50.54 | Val: 65.92
# Epoch 701 | Train: 50.66 | Val: 64.08
# EarlyStopping counter: 7 out of 2
# Epoch 701 | Train: 50.66 | Val: 64.08
# Epoch 702 | Train: 50.90 | Val: 60.95
# EarlyStopping counter: 8 out of 2
# Epoch 702 | Train: 50.90 | Val: 60.95
# Epoch 703 | Train: 50.76 | Val: 61.49
# EarlyStopping counter: 9 out of 2
# Epoch 703 | Train: 50.76 | Val: 61.49
# Epoch 704 | Train: 50.47 | Val: 61.53
# EarlyStopping counter: 10 out of 2
# Epoch 704 | Train: 50.47 | Val: 61.53
# Epoch 705 | Train: 50.76 | Val: 60.97
# EarlyStopping counter: 11 out of 2
# Epoch 705 | Train: 50.76 | Val: 60.97
# Epoch 706 | Train: 51.43 | Val: 61.78
# EarlyStopping counter: 12 out of 2
# Epoch 706 | Train: 51.43 | Val: 61.78
# Epoch 707 | Train: 51.14 | Val: 62.66
# EarlyStopping counter: 13 out of 2
# Epoch 707 | Train: 51.14 | Val: 62.66
# Epoch 708 | Train: 50.27 | Val: 63.82
# EarlyStopping counter: 14 out of 2
# Epoch 708 | Train: 50.27 | Val: 63.82
# Epoch 709 | Train: 52.45 | Val: 63.92
# EarlyStopping counter: 15 out of 2
# Epoch 709 | Train: 52.45 | Val: 63.92
# Epoch 710 | Train: 51.10 | Val: 62.93
# EarlyStopping counter: 16 out of 2
# Epoch 710 | Train: 51.10 | Val: 62.93
# EarlyStopping counter: 29 out of 2
# Epoch 775 | Train: 48.98 | Val: 61.40
# Epoch 776 | Train: 48.90 | Val: 60.90
# EarlyStopping counter: 30 out of 2
# Epoch 776 | Train: 48.90 | Val: 60.90
# Epoch 777 | Train: 48.85 | Val: 60.44
# EarlyStopping counter: 31 out of 2
# Epoch 777 | Train: 48.85 | Val: 60.44
# Epoch 778 | Train: 48.13 | Val: 64.02
# EarlyStopping counter: 32 out of 2
# Epoch 778 | Train: 48.13 | Val: 64.02
# Epoch 779 | Train: 48.59 | Val: 63.69
# EarlyStopping counter: 33 out of 2
# Epoch 779 | Train: 48.59 | Val: 63.69
# Epoch 780 | Train: 48.73 | Val: 61.84
# EarlyStopping counter: 34 out of 2
# Epoch 780 | Train: 48.73 | Val: 61.84
# Epoch 781 | Train: 48.63 | Val: 61.50
# EarlyStopping counter: 35 out of 2
# Epoch 781 | Train: 48.63 | Val: 61.50
# Epoch 782 | Train: 48.23 | Val: 59.26
# Validation loss decreased (59.257936 --> 59.257936).  Saving model ...
# Epoch 782 | Train: 48.23 | Val: 59.26
# Epoch 783 | Train: 49.10 | Val: 61.14
# EarlyStopping counter: 1 out of 2
# Epoch 783 | Train: 49.10 | Val: 61.14
# Epoch 784 | Train: 48.46 | Val: 61.20
# EarlyStopping counter: 2 out of 2
# Epoch 784 | Train: 48.46 | Val: 61.20
# Epoch 785 | Train: 49.59 | Val: 61.77
# EarlyStopping counter: 3 out of 2
# Epoch 785 | Train: 49.59 | Val: 61.77
# Epoch 786 | Train: 49.10 | Val: 64.65
# EarlyStopping counter: 4 out of 2
# Epoch 786 | Train: 49.10 | Val: 64.65
# Epoch 787 | Train: 48.15 | Val: 61.92
# EarlyStopping counter: 5 out of 2
# Epoch 787 | Train: 48.15 | Val: 61.92
# Epoch 788 | Train: 48.38 | Val: 60.46
# EarlyStopping counter: 6 out of 2
# Epoch 788 | Train: 48.38 | Val: 60.46
# Epoch 789 | Train: 48.90 | Val: 59.83
# EarlyStopping counter: 7 out of 2
# Epoch 789 | Train: 48.90 | Val: 59.83
# Epoch 790 | Train: 48.91 | Val: 61.08
# EarlyStopping counter: 8 out of 2
# Epoch 790 | Train: 48.91 | Val: 61.08
# Epoch 791 | Train: 48.14 | Val: 60.47
# EarlyStopping counter: 9 out of 2
# Epoch 791 | Train: 48.14 | Val: 60.47
# Epoch 792 | Train: 49.35 | Val: 61.98
# EarlyStopping counter: 10 out of 2
# Epoch 792 | Train: 49.35 | Val: 61.98
# Epoch 793 | Train: 48.81 | Val: 62.08
# EarlyStopping counter: 11 out of 2
# Epoch 793 | Train: 48.81 | Val: 62.08
# Epoch 794 | Train: 48.82 | Val: 63.92
# EarlyStopping counter: 12 out of 2
# Epoch 794 | Train: 48.82 | Val: 63.92
# Epoch 795 | Train: 48.77 | Val: 59.74
# EarlyStopping counter: 13 out of 2
# Epoch 795 | Train: 48.77 | Val: 59.74
# Epoch 796 | Train: 48.34 | Val: 66.98
# EarlyStopping counter: 14 out of 2
# Epoch 796 | Train: 48.34 | Val: 66.98
# Epoch 797 | Train: 48.45 | Val: 61.25
# EarlyStopping counter: 15 out of 2
# Epoch 797 | Train: 48.45 | Val: 61.25
# Epoch 798 | Train: 48.72 | Val: 59.16
# Validation loss decreased (59.162566 --> 59.162566).  Saving model ...
# Epoch 798 | Train: 48.72 | Val: 59.16
# Epoch 799 | Train: 48.27 | Val: 59.47
# EarlyStopping counter: 1 out of 2
# Epoch 799 | Train: 48.27 | Val: 59.47
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:851, in _check_seekable(f)
#     850 try:
# --> 851     f.seek(f.tell())
#     852     return True
#
# AttributeError: 'function' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 81
#      67     print(f'Epoch {epoch} | Train: {avg_train_loss:.2f} | Val: {avg_val_loss:.2f}')
#      69     # Save model checkpoint every checkpoint_increment epochs
#      70     # if (epoch + 1) % checkpoint_increment == 0:
#      71     #     checkpoint_path_file = f'{checkpoint_path}\RNN_VAE_checkpoint_epoch{epoch+1}.pth'
#    (...)
#      79 # --- LOAD BEST MODEL ---
#      80 # After the loop breaks, load the best saved weights
# ---> 81 model1.load_state_dict(torch.load(path))
#      82 print("Best model loaded.")
#      84 plot_model_loss(training_losses, validation_losses)
#
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:756, in _open_file_like(name_or_buffer, mode)
#     754     return _open_buffer_writer(name_or_buffer)
#     755 elif "r" in mode:
# --> 756     return _open_buffer_reader(name_or_buffer)
#     757 else:
#     758     raise RuntimeError(f"Expected 'r' or 'w' in mode but got {mode}")
#
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:741, in _open_buffer_reader.__init__(self, buffer)
#     739 def __init__(self, buffer):
#     740     super().__init__(buffer)
# --> 741     _check_seekable(buffer)
#
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:854, in _check_seekable(f)
#     852     return True
#     853 except (io.UnsupportedOperation, AttributeError) as e:
# --> 854     raise_err_msg(["seek", "tell"], e)
#     855 return False
#
# File k:\victor\python-project\torchenv\Lib\site-packages\torch\serialization.py:847, in _check_seekable.<locals>.raise_err_msg(patterns, e)
#     840     if p in str(e):
#     841         msg = (
#     842             str(e)
#     843             + ". You can only torch.load from a file that is seekable."
#     844             + " Please pre-load the data into a buffer like io.BytesIO and"
#     845             + " try to load from it instead."
#     846         )
# --> 847         raise type(e)(msg)
#     848 raise e
#
# AttributeError: 'function' object has no attribute 'seek'. You can only torch.load from a file that is seekable. Please pre-load the data into a buffer like io.BytesIO and try to load from it instead.
